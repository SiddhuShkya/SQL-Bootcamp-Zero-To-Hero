# %%
from sqlalchemy import create_engine, text
import pandas as pd

database = "learning"
engine = create_engine(f"postgresql://postgres:shakya2830@localhost:5432/{database}")

# ✅ Wrap query with text()
query = text("""
SELECT * FROM employees;
""")

df = pd.read_sql(query, engine)
df.head(5)
# Out:
#    emp_id  first_name last_name  birth_date   hire_date  salary
# 0       2        Jose  Portilla  1999-11-03  2010-01-01    1500
# 1       4  Siddhartha    Shakya  2003-09-05  2010-01-01     500
