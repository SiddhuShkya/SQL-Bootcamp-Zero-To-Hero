# %%
from sqlalchemy import create_engine, text
import pandas as pd

database = "school"
engine = create_engine(f"postgresql://postgres:shakya2830@localhost:5432/{database}")

# ✅ Wrap query with text()
query = text("""
SELECT * FROM teachers;
""")

df = pd.read_sql(query, engine)
df.head(5)
# Out:
#    teacher_id first_name last_name  homeroom_number department  \
# 0           1      Jonas      Salk                5    Biology
#
#               email         phone
# 0  jsalk@school.org  777-555-4321
