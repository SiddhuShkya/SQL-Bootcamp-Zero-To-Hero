# %%
from sqlalchemy import create_engine
import pandas as pd

engine = create_engine("postgresql://postgres:shakya2830@localhost:5432/dvdrental")

query = """
SELECT COUNT(*)
FROM payment
WHERE EXTRACT(dow FROM payment_date) = 1;
"""

df = pd.read_sql(query, engine)
df.head()
# Out:
#    count
# 0   2948
