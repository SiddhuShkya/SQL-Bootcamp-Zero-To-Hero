# %%
from sqlalchemy import create_engine
import pandas as pd

engine = create_engine("postgresql://postgres:shakya2830@localhost:5432/dvdrental")

query = """
SELECT LOWER(LEFT(first_name, 1)) || '.' || LOWER(last_name) || '@wlv.ac.uk' AS custom_email
FROM customer;
"""

df = pd.read_sql(query, engine)
df.head()
# Out:
#            custom_email
# 0       j.ely@wlv.ac.uk
# 1     m.smith@wlv.ac.uk
# 2   p.johnson@wlv.ac.uk
# 3  l.williams@wlv.ac.uk
# 4     b.jones@wlv.ac.uk
