# %%
import pandas as pd
from pandasql import sqldf

# %%
TABLE_NAME = "customer_table"
DATA_PATH = "../data/" + TABLE_NAME + ".csv"

df = pd.read_csv(DATA_PATH)
# Important: assign dataframe to variable matching table name
df_table = df
query = """
SELECT * FROM df_table
WHERE first_name LIKE 'A%'
ORDER BY first_name;
"""

result = sqldf(query, globals())
result.head(5)
# Out:
#    customer_id  store_id first_name last_name  \
# 0          375         2      Aaron     Selby
# 1          367         1       Adam     Gooch
# 2          525         2     Adrian     Clary
# 3          217         2      Agnes    Bishop
# 4          389         1       Alan      Kahn
#
#                              email  address_id  activebool create_date  \
# 0   aaron.selby@sakilacustomer.org         380           1  2006-02-14
# 1    adam.gooch@sakilacustomer.org         372           1  2006-02-14
# 2  adrian.clary@sakilacustomer.org         531           1  2006-02-14
# 3  agnes.bishop@sakilacustomer.org         221           1  2006-02-14
# 4     alan.kahn@sakilacustomer.org         394           1  2006-02-14
#
#                last_update  active
# 0  2013-05-26 14:49:45.738       1
# 1  2013-05-26 14:49:45.738       1
# 2  2013-05-26 14:49:45.738       1
# 3  2013-05-26 14:49:45.738       1
# 4  2013-05-26 14:49:45.738       1
