# %%
import pandas as pd
from pandasql import sqldf

# %%
TABLE_NAME1 = "union_example/sales2021_q1"
DATA_PATH1 = "../data/" + TABLE_NAME1 + ".csv"

TABLE_NAME2 = "union_example/sales2021_q2"
DATA_PATH2 = "../data/" + TABLE_NAME2 + ".csv"
df1 = pd.read_csv(DATA_PATH1)
df2 = pd.read_csv(DATA_PATH2)
# Important: assign dataframe to variable matching table name
df_table1 = df1
df_table2 = df2
query = """
SELECT * FROM df_table1
UNION
SELECT * FROM df_table2 
ORDER BY name DESC
"""

result = sqldf(query, globals())
result.head(10)
# Out:
#       name   amount
# 0    Sarah      150
# 1    Sarah      300
# 2  Michael      310
# 3     John      200
# 4     John      250
# 5    Emily      280
# 6    David      100
# 7    David      200
