# %%
import pandas as pd
from pandasql import sqldf

# %%
TABLE_NAME = "payment_table"
DATA_PATH = "../data/" + TABLE_NAME + ".csv"

df = pd.read_csv(DATA_PATH)
# Important: assign dataframe to variable matching table name
df_table = df
query = """
SELECT customer_id, SUM(amount) FROM df_table
WHERE staff_id = 2
GROUP BY customer_id
HAVING SUM(amount) > 100;
"""

result = sqldf(query, globals())
result.head(5)
# Out:
#    customer_id  SUM(amount)
# 0          148       110.78
# 1          187       110.81
# 2          211       108.77
# 3          522       102.80
# 4          526       101.78
