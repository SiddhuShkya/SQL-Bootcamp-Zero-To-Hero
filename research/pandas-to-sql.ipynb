# %%
import pandas as pd
from pandasql import sqldf

# %%
TABLE_NAME = "payment_table"
DATA_PATH = "../data/" + TABLE_NAME + ".csv"

df = pd.read_csv(DATA_PATH)
# Important: assign dataframe to variable matching table name
df_table = df
query = """
SELECT customer_id, SUM(amount) AS total_spent FROM df_table
GROUP BY customer_id
HAVING SUM(amount) > 100;
"""

result = sqldf(query, globals())
result.head(5)
# Out:
#    customer_id  total_spent
# 0            1       114.70
# 1            2       123.74
# 2            3       130.76
# 3            5       134.65
# 4            7       130.72
