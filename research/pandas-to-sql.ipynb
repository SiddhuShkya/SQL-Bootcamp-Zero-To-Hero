# %%
import pandas as pd
from pandasql import sqldf

# %%
TABLE_NAME = "film_table"
DATA_PATH = "../data/" + TABLE_NAME + ".csv"

df = pd.read_csv(DATA_PATH)
# Important: assign dataframe to variable matching table name
df_table = df
query = """
SELECT DISTINCT rating FROM df_table;
"""

result = sqldf(query, globals())
result.head()
# Out:
#   rating
# 0  NC-17
# 1      R
# 2  PG-13
# 3     PG
# 4      G
