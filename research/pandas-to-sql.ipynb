# %%
import pandas as pd
from pandasql import sqldf

# %%
TABLE_NAME1 = "payment_table"
DATA_PATH1 = "../data/" + TABLE_NAME1 + ".csv"

TABLE_NAME2 = "customer_table"
DATA_PATH2 = "../data/" + TABLE_NAME2 + ".csv"
df1 = pd.read_csv(DATA_PATH1)
df2 = pd.read_csv(DATA_PATH2)
# Important: assign dataframe to variable matching table name
df_table1 = df1
df_table2 = df2
query = """
SELECT payment_id, df_table1.customer_id, first_name
FROM df_table1
INNER JOIN df_table2
ON df_table1.customer_id = df_table2.customer_id;
"""

result = sqldf(query, globals())
result.head(5)
# Out:
#    payment_id  customer_id first_name
# 0       17503          341      Peter
# 1       17504          341      Peter
# 2       17505          341      Peter
# 3       17506          341      Peter
# 4       17507          341      Peter
